# %%
import json

categories=(
    "Alabama",
    "Alaska",
    "Arizona",
    "Arkansas",
    "California",
    "Colorado",
    "Connecticut",
    "Delaware",
    "District_of_Columbia",
    "Florida",
    "Georgia",
    "Hawaii",
    "Idaho",
    "Illinois",
    "Indiana",
    "Iowa",
    "Kansas",
    "Kentucky",
    "Louisiana",
    "Maine",
    "Maryland",
    "Massachusetts",
    "Michigan",
    "Minnesota",
    "Mississippi",
    "Missouri",
    "Montana",
    "Nebraska",
    "Nevada",
    "New_Hampshire",
    "New_Jersey",
    "New_Mexico",
    "New_York",
    "North_Carolina",
    "North_Dakota",
    "Ohio",
    "Oklahoma",
    "Oregon",
    "Pennsylvania",
    "Rhode_Island",
    "South_Carolina",
    "South_Dakota",
    "Tennessee",
    "Texas",
    "Utah",
    "Vermont",
    "Virginia",
    "Washington",
    "West_Virginia",
    "Wisconsin",
    "Wyoming"
)

# %% [markdown]
# ## examples

# %%
import subprocess

json.loads(
    subprocess.run("sed -n '1{p;q;}' Alabama.json", shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True).stdout)
# Out:
# {'name': 'Purple Peanut',
#  'address': 'Purple Peanut, 2357 Whitesburg Dr # D, Huntsville, AL 35801',
#  'gmap_id': '0x8862134e67ff5c87:0x38b5e2ae99cd1fcf',
#  'description': None,
#  'latitude': 34.7131627,
#  'longitude': -86.57404149999999,
#  'category': ['Boutique'],
#  'avg_rating': 4.6,
#  'num_of_reviews': 17,
#  'price': None,
#  'hours': [['Thursday', 'Closed'],
#   ['Friday', '10AM–5PM'],
#   ['Saturday', '10AM–3PM'],
#   ['Sunday', 'Closed'],
#   ['Monday', 'Closed'],
#   ['Tuesday', '10AM–5PM'],
#   ['Wednesday', '10AM–5PM']],
#  'MISC': {'Service options': ['In-store shopping', 'Delivery'],
#   'Accessibility': ['Wheelchair accessible entrance'],
#   'Planning': ['Quick visit']},
#  'state': 'Closed ⋅ Opens 10AM Fri',
#  'relative_results': ['0x886269389730ce8b:0xedffba4037968914',
#   '0x88626cba32c55791:0xb2b825009c312370',
#   '0x88626b52b85fa957:0x418f198557020e80',
#   '0x88626622a77eec85:0x71b49ce40b0a37f5',
#   '0x886269389730ce8b:0x1a711b728215c00a'],
#  'url': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x8862134e67ff5c87:0x38b5e2ae99cd1fcf?authuser=-1&hl=en&gl=us'}

# %%
import subprocess
import json

json.loads(
    subprocess.run("sed -n '10{p;q;}' Alabama.json", shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True).stdout)
# Out:
# {'name': 'Erin Lindsey Images, LLC',
#  'address': 'Erin Lindsey Images, LLC, 103 Andalusia Cir, Huntsville, AL 35811',
#  'gmap_id': '0x886215efe68553d7:0xb0685b9fde6d46fa',
#  'description': None,
#  'latitude': 34.801065,
#  'longitude': -86.510746,
#  'category': ['Wedding photographer'],
#  'avg_rating': 4.8,
#  'num_of_reviews': 4,
#  'price': None,
#  'hours': [['Wednesday', '8AM–5PM'],
#   ['Thursday', '8AM–5PM'],
#   ['Friday', '8AM–12PM'],
#   ['Saturday', 'Closed'],
#   ['Sunday', 'Closed'],
#   ['Monday', '8AM–5PM'],
#   ['Tuesday', '8AM–5PM']],
#  'MISC': None,
#  'state': 'Closed ⋅ Opens 8AM Thu',
#  'relative_results': ['0x88623b4fdd76aaab:0xd65f0e929565ee66',
#   '0x88626cabc3ac5f03:0xc4f52a035a5fcb50',
#   '0x88626bbed195bb5b:0xbd672d76d79f5850',
#   '0x886246eeaf78120f:0x1d07c8c1bfff6263',
#   '0x88625d5ea1a0d279:0xdf056a1b0062e727'],
#  'url': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x886215efe68553d7:0xb0685b9fde6d46fa?authuser=-1&hl=en&gl=us'}

# %%
import subprocess
import json

json.loads(
    subprocess.run("sed -n '10{p;q;}' Hawaii.json", shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True).stdout)
# Out:
# {'name': 'Mary Guava Designs',
#  'address': 'Mary Guava Designs, 45-3593 Mamane St, Honokaa, HI 96727',
#  'gmap_id': '0x79530ace67ee62b5:0xef6d8b0c8ee1cf79',
#  'description': None,
#  'latitude': 20.0791218,
#  'longitude': -155.46829689999998,
#  'category': ['Gift shop'],
#  'avg_rating': 5,
#  'num_of_reviews': 1,
#  'price': None,
#  'hours': [['Wednesday', '9:30AM–5:30PM'],
#   ['Thursday', '9:30AM–5:30PM'],
#   ['Friday', '9:30AM–5:30PM'],
#   ['Saturday', '9:30AM–5:30PM'],
#   ['Sunday', '11AM–3:30PM'],
#   ['Monday', '9:30AM–5:30PM'],
#   ['Tuesday', '9:30AM–5:30PM']],
#  'MISC': {'Service options': ['In-store shopping', 'Delivery'],
#   'Planning': ['Quick visit']},
#  'state': 'Closed ⋅ Opens 9:30AM Thu',
#  'relative_results': ['0x79530ace4231d127:0x5de70391d6d7b338',
#   '0x79530ace73d0bbc7:0x29fb8329db69bd63',
#   '0x79530acfa3e2855f:0x65376a31caf5078c',
#   '0x79530ace5ebb48df:0x531ae767fd0804e',
#   '0x79530ac46b0cdc19:0xddd7758a082b637f'],
#  'url': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x79530ace67ee62b5:0xef6d8b0c8ee1cf79?authuser=-1&hl=en&gl=us'}

# %%
import subprocess

results = []
line_number = 1
for c in categories:
    results.append(
                subprocess.run(f"sed -n '{line_number}{{p;q;}}' {c + '.json'}", shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True).stdout)
    
for r in results:
    r = json.loads(r)
    print(f"name: {r['name']}")
    print(f"category: {' | '.join(r['category'])}")
    print(f"description: {r['description']}")
    print("------------------------------------")
    # print({
    #     'title': r['title'],
    #     'features': r['features'],
    #     'description': r['description']
    # })
# Out:
# name: Purple Peanut
# category: Boutique
# description: None
# ------------------------------------
# name: Bear Creek Cabins & RV Park
# category: RV park | Cabin rental agency | Campground
# description: None
# ------------------------------------
# name: AZ Pool Works LLC
# category: Swimming pool repair service | Service establishment | Pool cleaning service | Swimming pool contractor
# description: None
# ------------------------------------
# name: Mitchell's Breakfast Burritos
# category: Restaurant | Breakfast restaurant | Lunch restaurant
# description: None
# ------------------------------------
# name: City Textile
# category: Textile exporter
# description: None
# ------------------------------------
# name: Balanced Body Center
# category: Chiropractor | Acupuncturist | Alternative medicine practitioner | Counselor | Family counselor | Holistic medicine practitioner | Marriage or relationship counselor | Massage therapist | Nutritionist | Psychotherapist
# description: None
# ------------------------------------
# name: Ghezzi's Package Store
# category: Wine store
# description: None
# ------------------------------------
# name: Beach Plum Dunes Apartments
# category: Apartment complex
# description: None
# ------------------------------------
# name: Cascade Café
# category: American restaurant
# description: Cafeteria-style dining at the National Gallery of Art, with casual fare such as pizza & sandwiches.
# ------------------------------------
# name: NTK OUTDOOR
# category: Corporate office
# description: None
# ------------------------------------
# name: Porter Pharmacy
# category: Pharmacy
# description: None
# ------------------------------------
# name: Hale Pops
# category: Restaurant
# description: None
# ------------------------------------
# name: Montour WMA - Idaho Fish and Game
# category: Hunting area
# description: None
# ------------------------------------
# name: The Toy House
# category: Toy store
# description: None
# ------------------------------------
# name: Majestic Security
# category: Security guard service | Business to business service | Public safety office | Security service | Training centre | Training school | Transportation escort service
# description: None
# ------------------------------------
# name: Polished Nail Salon & Spa
# category: Nail salon | Waxing hair removal service
# description: None
# ------------------------------------
# name: Knight Hawk
# category: Auto repair shop
# description: None
# ------------------------------------
# name: Farm Fresh Produce
# category: Grocery store
# description: None
# ------------------------------------
# name: KeyMe Locksmiths
# category: Locksmith | Emergency locksmith service | Key duplication service | Security system installer
# description: None
# ------------------------------------
# name: Enman Field Disc Golf Course
# category: Disc golf course
# description: None
# ------------------------------------
# name: My Express Care Pharmacy
# category: Pharmacy
# description: None
# ------------------------------------
# name: Grace Ryder Housing Center
# category: Senior citizen center
# description: None
# ------------------------------------
# name: Burnette Baptist Church
# category: Church
# description: None
# ------------------------------------
# name: Quantum Chiropractic Arts
# category: Chiropractor
# description: None
# ------------------------------------
# name: DJ Wes' Mobile DJ Service
# category: DJ service
# description: None
# ------------------------------------
# name: McAnulty Barry
# category: Counselor
# description: None
# ------------------------------------
# name: Big Sky Truck & Equipment, Inc.
# category: Truck accessories store | Diesel engine dealer | Used auto parts store
# description: None
# ------------------------------------
# name: Sunglass Hut
# category: Sunglasses store | Fashion accessories store | Gift shop | Shopping mall
# description: Chain retailer carrying a wide selection of trendy brand-name & designer sunglasses.
# ------------------------------------
# name: Onyx Bar
# category: Cocktail bar
# description: None
# ------------------------------------
# name: WindSong Acres
# category: Farm
# description: None
# ------------------------------------
# name: BELLIBONE
# category: Beauty salon
# description: None
# ------------------------------------
# name: The Ingles Company Realtors
# category: Real estate agency | Mortgage lender
# description: None
# ------------------------------------
# name: A-Top Insurance
# category: Insurance broker | Insurance agency
# description: None
# ------------------------------------
# name: CLR 27 building 1829
# category: Corporate office
# description: None
# ------------------------------------
# name: St Peter & Paul Church
# category: Catholic church
# description: None
# ------------------------------------
# name: Pleasant Valley Corporation
# category: General contractor | Construction company | Real estate developer
# description: None
# ------------------------------------
# name: Team Oil Tools
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#      10 r = json.loads(r)
#      11 print(f"name: {r['name']}")
# ---> 12 print(f"category: {' | '.join(r['category'])}")
#      13 print(f"description: {r['description']}")
#      14 print("------------------------------------")
#
# TypeError: can only join an iterable
